# %% [markdown]
# # Assignments

# %% [markdown]
#  ### Tier 1 - core

# %%
# working with rainfall file CombinedENACTSmonthly.nc

# 1. inspect dataset - what variables does it have? what dimensions?

# 2. extract rainfall variable into a dataarray

# 3. plot a map of long term mean rainfall

# 4. plot a time series of rainfall for approximate location of Tana

# 5. plot map of total annual rainfall in 2022

# %% [markdown]
# ### Tier 2 - applications

# %%
# 1. plot map of the highest monthly rainfall in 2022

# 2. plot time series of December rainfall for the location of Tana

# 3. plot long-term anomalies of December rainfall for the location of Tana

# 4. plot mean, minimum and maximum climatological rainfall for Tana

# 5. identify which year was the wettest on record and and one that was driest or record (over the entire domain)

# 6. plot the map showing rainfall range - difference between the wettest and driest year

# %% [markdown]
# ### Tier 3 - extension

# %%
# 1. identify the 5 wettest and 5 driest Decembers (over the entire domain). 
# Calculate and plot maps of their means. 
# Calculate and plot composite anomaly for these years

# %%
# 2. plot time series of total annual rainfall for the grid cell with the highest and the lowest mean long term rainfall
